# %%
# SLM copy debug
import openpyxl 
import string
import pandas as pd
from pandas import ExcelWriter
import numpy as np
from openpyxl import load_workbook
from openpyxl import Workbook
from openpyxl import cell
from openpyxl.utils import get_column_letter
import xlsxwriter
import matplotlib.pyplot as plot
from os import listdir, walk
from os.path import isfile, join
import tkinter as tk
from tkinter import *

# %%
testplan_path ='TestPlan_VAclinic_ASTM_testingv1.xlsx'
# testplan_path ='TestPlan_23-010_SkyAlaMoana_ASTM_testingv1.xlsx'
# write an input here

# testplanfile = openpyxl.load_workbook(testplan_path)
# testlist = testplanfile['Table 2']
# test_num = testlist['C3:C9']
# source_slm_num = testlist['J3:J9']
# receive_slm_num = testlist['K3:K9']
# bkgnd_slm_num = testlist['L3:L9']
# rt_slm_num = testlist['M3:M9']

# %%
rawDtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw_Data/Meter D - 3784/'
rawEtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw_Data/Meter E - 4328/'

D_datafiles = [f for f in listdir(rawDtestpath) if isfile(join(rawDtestpath,f))]
E_datafiles = [f for f in listdir(rawEtestpath) if isfile(join(rawEtestpath,f))]
rawReportpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Documents/python_files/ASTC_reports/tester/'
reports =  [f for f in listdir(rawReportpath) if isfile(join(rawReportpath,f))]

# %%
test_list = pd.read_excel(testplan_path)
print(test_list)

# %%
def write_testdata(find_datafile, reportfile, newsheetname):
    if find_datafile[0] =='D':
        datafile_num = find_datafile[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        slm_found = [x for x in D_datafiles if datafile_num in x]
        slm_found[0] = rawDtestpath+slm_found[0]
        # print(srs_slm_found)
    elif find_datafile[0] == 'E':
        datafile_num = find_datafile[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        slm_found = [x for x in E_datafiles if datafile_num in x]
        slm_found[0] = rawEtestpath+slm_found[0]

    print(slm_found[0])

    srs_data = pd.read_excel(slm_found[0],sheet_name='OBA')
    with ExcelWriter(
    rawReportpath+reportfile,
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        srs_data.to_excel(writer, sheet_name=newsheetname) 

def write_RTtestdata(find_datafile, reportfile,newsheetname):
    if find_datafile[0] =='D':
        datafile_num = find_datafile[1:]
        datafile_num = '-RT_Data.'+datafile_num+'.xlsx'
        slm_found = [x for x in D_datafiles if datafile_num in x]
        slm_found[0] = rawDtestpath+slm_found[0]
        # print(srs_slm_found)
    elif find_datafile[0] == 'E':
        datafile_num = find_datafile[1:]
        datafile_num = '-RT_Data.'+datafile_num+'.xlsx'
        slm_found = [x for x in E_datafiles if datafile_num in x]
        slm_found[0] = rawEtestpath+slm_found[0]

    print(slm_found[0])

    srs_data = pd.read_excel(slm_found[0],sheet_name='Summary')
    with ExcelWriter(
    rawReportpath+reportfile,
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        srs_data.to_excel(writer, sheet_name=newsheetname)

# %%
#### old debug tester without functions ### 
test_list = pd.read_excel(testplan_path)
testnums = test_list['Test Label']
# testnums = ['1.4.0']
for i in range(len(testnums)):
    curr_test = test_list.iloc[i]
    find_report = curr_test['Test Label']
    report_string = '_'+find_report+'_'
    curr_report_file = [x for x in reports if report_string in x]
    print(curr_report_file[0])
    

    find_source = curr_test['Source']
    find_rec = curr_test['Recieve ']
    find_BNL = curr_test['BNL']
    find_RT = curr_test['RT']

    # print(find_source)

    if find_source[0] =='D':
        datafile_num = find_source[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        srs_slm_found = [x for x in D_datafiles if datafile_num in x]
        srs_slm_found[0] = rawDtestpath+srs_slm_found[0]
        # print(srs_slm_found)
    elif find_source[0] == 'E':
        datafile_num = find_source[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        srs_slm_found = [x for x in E_datafiles if datafile_num in x]
        srs_slm_found[0] = rawEtestpath+srs_slm_found[0]

    print(srs_slm_found[0])

    srs_data = pd.read_excel(srs_slm_found[0],sheet_name='OBA')
    with ExcelWriter(
    rawReportpath+curr_report_file[0],
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        srs_data.to_excel(writer, sheet_name="Auto Source") 

    if find_rec[0] =='D':
        datafile_num = find_rec[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        rec_slm_found = [x for x in D_datafiles if datafile_num in x]
        rec_slm_found[0] = rawDtestpath+rec_slm_found[0]
        # print(srs_slm_found)
    elif find_rec[0] == 'E':
        datafile_num = find_rec[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        rec_slm_found = [x for x in E_datafiles if datafile_num in x]
        rec_slm_found[0] = rawEtestpath+rec_slm_found[0]
    print(rec_slm_found[0])
    rec_data = pd.read_excel(rec_slm_found[0], sheet_name='OBA')
    with ExcelWriter(
    rawReportpath+curr_report_file[0],
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        rec_data.to_excel(writer, sheet_name="Auto Recieve")

    if find_BNL[0] =='D':
        datafile_num = find_BNL[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        bkgnd_slm_found = [x for x in D_datafiles if datafile_num in x]
        bkgnd_slm_found[0] = rawDtestpath+bkgnd_slm_found[0]
    elif find_BNL[0] == 'E':
        datafile_num = find_BNL[1:]
        datafile_num = '-831_Data.'+datafile_num+'.xlsx'
        bkgnd_slm_found = [x for x in E_datafiles if datafile_num in x]
        bkgnd_slm_found[0] = rawEtestpath+bkgnd_slm_found[0]
    print(bkgnd_slm_found)
    bkgnd_data = pd.read_excel(bkgnd_slm_found[0], sheet_name='OBA')
    with ExcelWriter(
    rawReportpath+curr_report_file[0],
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        bkgnd_data.to_excel(writer, sheet_name="Auto BKGD")
    
    if find_RT[0] =='D':
        datafile_num = find_RT[1:]
        datafile_num = '-RT_Data.'+datafile_num+'.xlsx'
        RT_slm_found = [x for x in D_datafiles if datafile_num in x]
        RT_slm_found[0] = rawDtestpath+RT_slm_found[0]
    elif find_RT[0] == 'E':
        datafile_num = find_RT[1:]
        datafile_num = '-RT_Data.'+datafile_num+'.xlsx'
        RT_slm_found = [x for x in E_datafiles if datafile_num in x]
        RT_slm_found[0] = rawEtestpath+RT_slm_found[0]
    print(RT_slm_found)
    RT_slm_found = pd.read_excel(RT_slm_found[0], sheet_name='Summary')
    RT_Data = RT_slm_found['Unnamed: 10']
    with ExcelWriter(
    rawReportpath+curr_report_file[0],
    mode="a",
    engine="openpyxl",
    if_sheet_exists="replace",
    ) as writer:
        RT_Data.to_excel(writer, sheet_name="Auto RT")

# %%
#IIC testlist only 
# must have underscores in the report filenames around test label: _1.1.0_
testplan_path ='TestPlan_23-010_SkyAlaMoana_IIC_testingv1.xlsx'
rawReportpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Documents/python_files/IIC_reports/tester/'
reports =  [f for f in listdir(rawReportpath) if isfile(join(rawReportpath,f))]
test_list = pd.read_excel(testplan_path)
testnums = test_list['Test Label']
# testnums = ['1.4.0']
for i in range(len(testnums)):
    curr_test = test_list.iloc[i]
    find_report = curr_test['Test Label']
    report_string = '_'+find_report+'_'
    curr_report_file = [x for x in reports if report_string in x]
    print(curr_report_file[0])

    ## ASTC variables
    find_source = curr_test['Source']
    find_rec = curr_test['Recieve ']
    find_BNL = curr_test['BNL']
    find_RT = curr_test['RT']
    
    ## IIC variables
    find_posOne = curr_test['Position1']
    find_posTwo = curr_test['Position2']
    find_posThree = curr_test['Position3']
    find_posFour = curr_test['Position4']
    find_poscarpet = curr_test['Carpet']
    find_Tapsrs = curr_test['SourceTap']

    write_testdata(find_source,curr_report_file[0],'ASTC Source')
    write_testdata(find_rec,curr_report_file[0],'ASTC Receive')
    write_testdata(find_BNL,curr_report_file[0],'BNL')
    write_RTtestdata(find_RT,curr_report_file[0],'RT')
    write_testdata(find_posOne,curr_report_file[0],'AIIC POS 1')
    write_testdata(find_posTwo,curr_report_file[0],'AIIC POS 2')
    write_testdata(find_posThree,curr_report_file[0],'AIIC POS 3')
    write_testdata(find_posFour,curr_report_file[0],'AIIC POS 4')
    write_testdata(find_poscarpet,curr_report_file[0],'AIIC CARPET')
    write_testdata(find_Tapsrs,curr_report_file[0],'AIIC Source')
# Out:
# 23-010 ASTC-NIC-AIIC-ISR Test Report_1.1.0_Unit13101210auto.xls
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter D - 3784/831_0003784-20230411 115001-831_Data.605.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230411 114943-831_Data.058.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230411 114827-831_Data.057.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230411 123511-RT_Data.080.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# ...

# %%
print(reports[4])
curr_test = test_list.iloc[i]
find_report = curr_test['Test Label']
report_string = '_'+find_report+'_'
print(report_string)
curr_report_file = [x for x in reports if report_string in x]
print(reports)
# Out:
# 23-010_Sky Ala Moana_1.7.0_ASTC-NIC Test Report_4-18-23.xlsx
# _1.1.0_
# ['23-010_Sky Ala Moana_1.10.0_ASTC-NIC Test Report_4-18-23.xlsx', '23-010_Sky Ala Moana_1.4.0_ASTC-NIC Test Report_4-18-23.xlsx', '23-010_Sky Ala Moana_1.5.0_ASTC-NIC Test Report_4-18-23 .xlsx', '23-010_Sky Ala Moana_1.6.0_ASTC-NIC Test Report_4-18-23.xlsx', '23-010_Sky Ala Moana_1.7.0_ASTC-NIC Test Report_4-18-23.xlsx', '23-010_Sky Ala Moana_1.8.0_ASTC-NIC Test Report_4-18-23.xlsx', '23-010_Sky Ala Moana_1.9.0_ASTC-NIC Test Report_4-18-23.xlsx']

# %%
#ASTC testlist only 
# must have underscores in the report filenames around test label: _1.1.0_
testplan_path ='TestPlan_VAclinic_ASTM_testingv1.xlsx'
rawReportpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Documents/ASTC_reports/'

reports =  [f for f in listdir(rawReportpath) if isfile(join(rawReportpath,f))]
## testplan list datastruct, assigning SLM files to the appropriate test numbers and corresponding rooms
test_list = pd.read_excel(testplan_path)
testnums = test_list['Test Label']
#### SLM data filepaths #### 
rawDtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw Data/Meter D - 3784/'
rawEtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw_Data/Meter E - 4328/'
D_datafiles = [f for f in listdir(rawDtestpath) if isfile(join(rawDtestpath,f))]
E_datafiles = [f for f in listdir(rawEtestpath) if isfile(join(rawEtestpath,f))]

# testnums = ['1.4.0']
for i in range(len(testnums)):
    curr_test = test_list.iloc[i]
    find_report = curr_test['Test Label']
    report_string = '_'+find_report+'_'
    curr_report_file = [x for x in reports if report_string in x]
    print(curr_report_file[0])

    ## ASTC variables
    find_source = curr_test['Source']
    find_rec = curr_test['Recieve ']
    find_BNL = curr_test['BNL']
    find_RT = curr_test['RT']
    # find_NIC_test = curr_test['NIC']
    
    write_testdata(find_source,curr_report_file[0],'Auto Source')
    write_testdata(find_rec,curr_report_file[0],'Auto Receieve')
    write_testdata(find_BNL,curr_report_file[0],'Auto BKGND')
    write_RTtestdata(find_RT,curr_report_file[0],'Auto RT')

# %%
#ASTC testlist only 
# must have underscores in the report filenames around test label: _1.1.0_
testplan_path ='TestPlan_VAclinic_ASTM_testingv1.xlsx'
rawReportpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Documents/ASTC_reports/'
reports =  [f for f in listdir(rawReportpath) if isfile(join(rawReportpath,f))]
## testplan list datastruct, assigning SLM files to the appropriate test numbers and corresponding rooms
test_list = pd.read_excel(testplan_path)
testnums = test_list['Test Label']
#### SLM data filepaths #### 
rawDtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw Data/Meter D - 3784/'
rawEtestpath = '//DLA-04/Shared/KAILUA PROJECTS/2023/P23-154 Aloha VA Clinic ASTM Testing/Test Data/Raw_Data/Meter E - 4328/'
D_datafiles = [f for f in listdir(rawDtestpath) if isfile(join(rawDtestpath,f))]
E_datafiles = [f for f in listdir(rawEtestpath) if isfile(join(rawEtestpath,f))]

# testnums = ['1.4.0']
for i in range(len(testnums)):
    curr_test = test_list.iloc[i]
    find_report = curr_test['Test Label']
    report_string = '_'+find_report+'_'
    curr_report_file = [x for x in reports if report_string in x]
    print(curr_report_file[0])

    ## ASTC variables
    find_source = curr_test['Source']
    find_rec = curr_test['Recieve ']
    find_BNL = curr_test['BNL']
    find_RT = curr_test['RT']
    find_NIC_test = curr_test['NIC']
    
    write_testdata(find_source,curr_report_file[0],'Auto Source')
    write_testdata(find_rec,curr_report_file[0],'Auto Receieve')
    write_testdata(find_BNL,curr_report_file[0],'Auto BKGND')
    write_RTtestdata(find_RT,curr_report_file[0],'Auto RT')
# Out:
# 23-010_Sky Ala Moana_1.4.0_ASTC-NIC Test Report_4-18-23.xlsx
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter D - 3784/831_0003784-20230414 101728-831_Data.615.xlsx
# AIIC Report
# ASTC Report
# ISR Report
# NIC Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230414 101726-831_Data.075.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230414 101132-831_Data.073.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# //DLA-04/Shared/KAILUA PROJECTS/2023/23-010 Sky Ala Moana ASTM Testing/Test Data/Raw Data/Meter E - 4328/831_0004328-20230414 102423-RT_Data.084.xlsx
# ASTC Report
# NIC Report
# AIIC Report
# ISR Report
# 23-010_Sky Ala Moana_1.5.0_ASTC-NIC Test Report_4-18-23 .xlsx
# ...

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib.units import inch
from reportlab.lib import colors
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.platypus import BaseDocTemplate, PageTemplate, Frame, Paragraph, Table, TableStyle, Spacer, PageBreak, KeepInFrame

# Sample data
source_room_name = "2nd Floor Bed 3"
rec_roomName = "1st Floor Bed 3"
sitename = "Ka'ulu by Gentry"
client_Name = "Gentry Builders, LLC"
reportdate = "4-24-24"
testdate = "4-3-24"
testnum = '1.1.1'
tested_assem = "partition"
left_margin = right_margin = 0.75 * 72  # 0.75 inches
top_margin = 0.25 * 72 # 0.25 inch
bottom_margin = 1 * 72  # 1 inch
header_height = 2 * inch
footer_height = 0.5 * inch
main_content_height = letter[1] - top_margin - bottom_margin - header_height - footer_height
# Custom margins and frame dimensions


# Initialize BaseDocTemplate
doc = BaseDocTemplate("report_with_header_footer.pdf", pagesize=letter,
                      leftMargin=left_margin, rightMargin=right_margin,
                      topMargin=top_margin, bottomMargin=bottom_margin)

# Define Frames for the header, main content, and footer
header_frame = Frame(left_margin, letter[1] - top_margin - header_height, letter[0] - 2 * left_margin, header_height, id='header')
main_frame = Frame(left_margin, bottom_margin + footer_height, letter[0] - 2 * left_margin, letter[1] - top_margin - header_height - footer_height - bottom_margin, id='main')
footer_frame = Frame(left_margin, bottom_margin, letter[0] - 2 * left_margin, footer_height, id='footer')

# Create styles
styles = getSampleStyleSheet()
custom_title_style = styles['Heading1']

# Define header elements
def header_elements():
    elements = []
    elements.append(Paragraph("<b>Field Impact Sound Transmission Test Report</b>", custom_title_style))
    elements.append(Paragraph("<b>Apparent Impact Insulation Class (AIIC)</b>", custom_title_style))
    elements.append(Spacer(1, 10))
    leftside_data = [
        ["Report Date:", reportdate],
        ['Test Date:', testdate],
        ['DLAA Test No', testnum]
    ]
    rightside_data = [
        ["Source Room:", source_room_name],
        ["Receiver Room:", rec_roomName],
        ["Test Assembly:", tested_assem]
    ]

    table_left = Table(leftside_data)
    table_right = Table(rightside_data)
    table_left.setStyle(TableStyle([('GRID', (0, 0), (-1, -1), 1, colors.black)]))
    table_right.setStyle(TableStyle([('GRID', (0, 0), (-1, -1), 1, colors.black)]))

    table_combined_lr = Table([[table_left, table_right]], colWidths=[doc.width / 2.0] * 2)
    elements.append(KeepInFrame(maxWidth=doc.width, maxHeight=header_height, content=[table_combined_lr], hAlign='LEFT'))
    elements.append(Spacer(1, 10))
    elements.append(Paragraph('Test site: ' + sitename, styles['Normal']))
    elements.append(Spacer(1, 5))
    elements.append(Paragraph('Client: ' + client_Name, styles['Normal']))
    return elements

# Define a function to draw the header and footer
def header_footer(canvas, doc):
    canvas.saveState()

    # Build the header
    header_frame._leftPadding = header_frame._rightPadding = 0
    header_story = header_elements()
    header_frame.addFromList(header_story, canvas)

    # Footer
    canvas.setFont('Helvetica', 10)
    footer_text = f"Page {doc.page}"
    canvas.drawCentredString(letter[0] / 2, bottom_margin + footer_height / 2, footer_text)

    canvas.restoreState()

# Create a page template with header and footer
page_template = PageTemplate(id='Standard', frames=[main_frame, header_frame, footer_frame], onPage=header_footer)
doc.addPageTemplates([page_template])

# Main document content
main_elements = [
    Paragraph("This is the main body text on the LAST page.  ", styles['Normal']),
    PageBreak(),
    Paragraph("This is text on the second page after a page break.", styles['Normal'])
]

# Build the document
doc.build(main_elements)
### THIS WORKS USE THIS ###
